# %%
import pandas as pd

# %%
results = pd.read_csv('test-results.csv')

# %%
results.head()
# Out:
#   embedding_type  max_depth         time   roc_auc    tp       fp       tn  \
# 0        nohcpcs          4  3968.163688  0.895967  5377  1638959  5805795
# 1        nohcpcs          4  3968.176243  0.895967  5377  1638959  5805795
# 2        nohcpcs          4  4271.500889  0.895967  5377  1638959  5805795
# 3         onehot          4  7289.428789  0.897691  5233  1457330  5987424
# 4        nohcpcs          8  7878.867157  0.936842  5518  1153085  6291669
#
#      fn       tpr       tnr  geometric_mean  arithmetic_mean  f1_score  \
# 0   958  0.848777  0.779850        0.813584         0.814314  0.006515
# 1   958  0.848777  0.779850        0.813584         0.814314  0.006515
# 2   958  0.848777  0.779850        0.813584         0.814314  0.006515
# 3  1102  0.826046  0.804247        0.815074         0.815147  0.007125
# 4   817  0.871034  0.845114        0.857976         0.858074  0.009473
#
#    precision  threshold
# 0   0.003270     0.0008
# 1   0.003270     0.0008
# ...

# %%
results.groupby(by=['embedding_type', 'max_depth']).count()
# Out:
#                           time  roc_auc  tp  fp  tn  fn  tpr  tnr  \
# embedding_type max_depth
# nohcpcs        4            25       25  25  25  25  25   25   25
#                8            25       25  25  25  25  25   25   25
# onehot         4            15       15  15  15  15  15   15   15
#                8            15       15  15  15  15  15   15   15
#
#                           geometric_mean  arithmetic_mean  f1_score  \
# embedding_type max_depth
# nohcpcs        4                      25               25        25
#                8                      25               25        25
# onehot         4                      15               15        15
#                8                      15               15        15
#
#                           precision  threshold
# embedding_type max_depth
# nohcpcs        4                 25         25
#                8                 25         25
# onehot         4                 15         15
# ...
